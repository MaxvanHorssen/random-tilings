# %%
from RandomTilings import *
import numpy as np

# %%
n=7
w = np.array([[1]])
# gap = np.array([[9,1,5]])
# gap = np.array([[8,1,4]])

gap = np.array([[4,-2,-1],[8,0,2],[7,0,2],[13,0,4],[2,-2,-2]])

vec,fig = draw_aztec_gap(n,w,gap,edge=1,dpi=100,rotated=True,paths=True,show_gap=True)
print(vec)
# Out:
# [(-8.903601611490199+0j), (10.50451944418825+0j), (19.40812105567845+0j)]

# %%
# Empty
n = 7
w = np.array([[1,1]]).T
gap = np.array([[3,1/2,3/2],[8,6+0.5,9+2]])

vec,fig = draw_hexagon_gap(n,w,gap,edge=1,dpi=100,paths=True,skewed_grid=False,show_gap=True)
print(vec)
print(np.exp(vec))
# Ml: Pn=3.3295e-09, ZnNum=1.3120e+08, and ZnDen=3.9406e+16
# Py: Pn=3.3295e-09, ZnNum=1.3120e+08, and ZnDen=3.9406e+16
# Out:
# [(-30.668362282403884+0j), (7.544332108053693+0j), (38.21269439045758+0j)]
# [4.79622437e-14+0.j 1.89000000e+03+0.j 3.94059963e+16+0.j]
