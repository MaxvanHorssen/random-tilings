# %%
import numpy as np  
import RandomTilingsV2 as RT

# %%
n = 10
w = np.array([[1]])
A = RT.Aztec(n,w)
B = RT.Hexagon(n,w)

# %%
B.shuffel()

# %%
B.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 B.plot()
#
# File c:\Users\u0173400\OneDrive - KU Leuven\Projects\random-tilings\RandomTilingsV2\RT.py:86, in RT.plot(self, **args)
#      84     print('The Random Tiling needs to be shuffeld first!')
#      85 else:
# ---> 86     return self.__plot(self.__M,**args)
#
# File c:\Users\u0173400\OneDrive - KU Leuven\Projects\random-tilings\RandomTilingsV2\RT.py:119, in Hexagon.<locals>.draw_Hexagon(M, skewed_grid, edge, paths, dots, coloring, dpi, show_figure)
#     117 def draw_Hexagon(M,skewed_grid=False,edge=0,paths=False,dots=False,coloring='standard',dpi=100,show_figure=False):
#     118     edge = str(edge)
# --> 119     fig = draw_lozenges(n,M,False,a,b,c,skewed_grid,edge,paths,dots,coloring,False,dpi,show_figure)
#     120     return fig
#
# ...

# %%
A.total_storage
# Out:
# 24.06 KB

# %%
A.shuffel()

# %%
#A.shuffel()
fig = A.plot(edge=0)
