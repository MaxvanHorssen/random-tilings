# %%
import numpy as np  
import RandomTilingsV2 as RT

# %%
n = 1
w = np.array([[1]])
B = RT.Hexagon(n,w,1,2,1)
B.shuffle()
B.plot()

# %%
B?
# Out:
# Type:        RT
# String form:
# Hexagon Tiling
# n = 1, a = 1, b = 2, c = 1
# Size = 4
# Weight
# [[1.]]
# File:        c:\users\u0173400\onedrive - ku leuven\projects\random-tilings\randomtilingsv2\_rt.py
# Docstring:   jo

# %%
A = RT.Aztec(n,w)
A
# Out:
# Aztec Diamond of size n = 50
# with Weight
# [[1]]

# %%
A.plot?
# Out:
# Signature: A.plot(**args)
# Docstring:
# This function creates a figure containing the plot of the Random Tiling.
#
# Inputs:
# ---------
#  - edge        : float (default = 0.); draws edges around the tiles with width 'edge'.
#                  Alternative it can be set to 'ede scaling', to set the edge width in
#                  comparison to the plot size.
#  - paths       : boolean (default = False); if True the random paths associated to the
#                  random tiling will be displayed.
#  - dots        : boolean (default = False); if True and paths = True, then the particles
#                  of associated determinental point process will be displayed.
#  - coloring    : str or rgb colors, options are 'standard', 'alternative' and 'gray'.
#                  For the aztec diamond, we also have the option 'aztec gray'/
#  - dpi         : integer (default = 100); resolution of the created plot.
# ...

# %%
A.shuffle()
A.plot()

# %%
M = A._RT__M.copy()

# %%
A.shuffle()
A._RT__M = M
A.plot()

# %%
A.plot()
# Out:
# Random Tiling is already closed, create a new one!

# %%
A.shuffle()
A.plot(dots=1,paths=1,rotated=0,edge=0.3)

# %%
A = 1
B = 1
C = 1

# %%
n = 20
w = np.array([[1]])
A = RT.Hexagon(n,w)

# %%
A.shuffle()
A.plot(edge=1,paths=1)

# %%
A.plot()

# %%
fig

# %%
n = 1                                 # Side length
a,b,c = 120,120,80                    # Side length multiplicators
w = np.array([[1,1]]).T               # Weighting matrix
gap = np.array([[130,100.5,140.5]])
C = RT.Hexagon(n,w,a,b,c,gap)

# %%
C.shuffle()
C.plot()

# %%
C.plot?
# Out:
# Signature: C.plot(**args)
# Docstring: <no docstring>
# File:      c:\users\u0173400\onedrive - ku leuven\projects\random-tilings\randomtilingsv2\_rt.py
# Type:      method

# %%
if np.array([1,1])==False:
    print('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 if np.array([1,1])==False:
#       2     print('hi')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
_ = B.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 _ = B.plot()
#
# AttributeError: 'int' object has no attribute 'plot'

# %%
A.total_storage
# Out:
# 24.06 KB

# %%
A.shuffel()

# %%
#A.shuffel()
fig = A.plot(edge=0)
